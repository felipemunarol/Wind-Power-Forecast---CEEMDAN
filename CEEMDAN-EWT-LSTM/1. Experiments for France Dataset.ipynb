# %%
import os

# import tensorflow as tf
# tf.config.experimental.enable_op_determinism()

# %%
import keras
keras.__version__
# Out:
# 2026-04-21 18:43:29.415617: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-21 18:43:29.436249: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-21 18:43:29.436275: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-21 18:43:29.437020: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-21 18:43:29.441023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-21 18:43:29.802002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# '2.15.0'

# %% [markdown]
# **Load Data**

# %%
import pandas as pd
df = pd.read_csv('/home/felipe/doutorado/pwf_ceemdan/dataset/final_la_haute_R0711.csv')
df['Date'] = pd.to_datetime(df['Date_time'])
df['Year'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month 
new_data=df[['Month','Year','Date','P_avg']]
new_data=new_data[new_data.Year == 2017]

cap=max(new_data['P_avg'])

# %% [markdown]
# **Parameter Settings**

# %%
i=[1] #enter month value, i.e January = 1
look_back=6
data_partition=0.8

# %%
from myfunctions_france import svr_model,ann_model,rf_model,lstm_model,emd_lstm,eemd_lstm,ceemdan_lstm,proposed_method

# %%
CUDA_VISIBLE_DEVICES=""

# %%
svr_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 5.459492254529992
# RMSE 165.76881245633513
# MAE 111.95671030570337

# %%
ann_model(new_data,i,look_back,data_partition,cap)
# Out:
# 2026-04-21 18:44:13.783250: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.041840: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.041885: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.043506: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.043541: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.043559: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.144439: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.144483: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.144488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-04-21 18:44:14.144513: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-21 18:44:14.144530: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2026-04-21 18:44:14.719225: W external/local_xla/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:504] Can't find libdevice directory ${CUDA_DIR}/nvvm/libdevice. This may result in compilation or runtime failures, if the program we try to run uses routines from libdevice.
# Searched for CUDA in the following directories:
#   ./cuda_sdk_lib
#   /usr/local/cuda-12.2
#   /usr/local/cuda
#   /home/felipe/.local/lib/python3.10/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc
#   /home/felipe/.local/lib/python3.10/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc
#   .
# You can choose the search directory by setting xla_gpu_cuda_data_dir in HloModule's DebugOptions.  For most apps, setting the environment variable XLA_FLAGS=--xla_gpu_cuda_data_dir=/path/to/cuda will work.
# 2026-04-21 18:44:14.733935: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.743455: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.743495: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.750179: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.750216: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.750279: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.750330: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.757410: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.757445: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.757599: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.757639: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.764124: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.764165: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.764293: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.764327: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.772261: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.772301: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.772380: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.772421: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.780459: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.780521: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.780591: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.780628: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.788325: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.788370: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.788416: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.788450: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.795250: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.795291: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.795358: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.795382: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2026-04-21 18:44:14.804936: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-04-21 18:44:14.804991: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2026-04-21 18:44:14.934542: I external/local_xla/xla/service/service.cc:168] XLA service 0x7116f19469e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-21 18:44:14.934581: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2026-04-21 18:44:14.938359: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-04-21 18:44:14.953060: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2026-04-21 18:44:14.959802: W external/local_xla/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:542] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.960453: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:574 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.972979: W external/local_xla/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:542] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.973569: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:574 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.986577: W external/local_xla/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:542] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.987164: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:574 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.998949: W external/local_xla/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:542] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2026-04-21 18:44:14.999381: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:574 : INTERNAL: libdevice not found at ./libdevice.10.bc
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ann_model(new_data,i,look_back,data_partition,cap)
#
# File ~/doutorado/pwf_ceemdan/CEEMDAN-EWT-LSTM/myfunctions_france.py:195, in ann_model(new_data, i, look_back, data_partition, cap)
#     192 optimizer = tf.keras.optimizers.Adam()
#     193 model.compile(loss='mse',optimizer=optimizer)
# --> 195 model.fit(trainX1, y,verbose=0)
#     197 # make predictions
#     198 y_pred_train = model.predict(trainX1)
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node Adam/StatefulPartitionedCall_3 defined at (most recent call last):
#   File "/home/felipe/miniconda3/envs/ceendam/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/home/felipe/miniconda3/envs/ceendam/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/felipe/miniconda3/envs/ceendam/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/home/felipe/miniconda3/envs/ceendam/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/home/felipe/miniconda3/envs/ceendam/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_72863/2751467334.py", line 1, in <module>
#
#   File "/home/felipe/doutorado/pwf_ceemdan/CEEMDAN-EWT-LSTM/myfunctions_france.py", line 195, in ann_model
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1154, in train_step
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 544, in minimize
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 1223, in apply_gradients
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 652, in apply_gradients
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 1253, in _internal_apply_gradients
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 1345, in _distributed_apply_gradients_fn
#
#   File "/home/felipe/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 1340, in apply_grad_to_update_var
#
# libdevice not found at ./libdevice.10.bc
# 	 [[{{node Adam/StatefulPartitionedCall_3}}]] [Op:__inference_train_function_808]

# %%
rf_model(new_data,i,look_back,data_partition,cap)

# %%
lstm_model(new_data,i,look_back,data_partition,cap)

# %%
emd_lstm(new_data,i,look_back,data_partition,cap)

# %%
eemd_lstm(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_lstm(new_data,i,look_back,data_partition,cap)

# %%
proposed_method(new_data,i,look_back,data_partition,cap)
